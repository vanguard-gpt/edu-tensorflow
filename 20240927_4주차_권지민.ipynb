# %%
# 10_MNIST_LEARN

import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
import tensorflow.keras.datasets as ds

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam

(x_train, y_train), (x_test, y_test) = ds.mnist.load_data()

x_train = x_train.reshape(60000,784)  # 3D --> 2D  reshaping
x_test = x_test.reshape(10000,784)

x_train = x_train.astype(np.float32)/255.0 # nomarlization
x_test = x_test.astype(np.float32)/255.0
print(x_train.shape)

y_train = tf.keras.utils.to_categorical(y_train, 10) # to one-hot enc
y_test = tf.keras.utils.to_categorical(y_test, 10)
print(y_train.shape)

n_input = 784
n_hidden = 1024
n_output = 10

mlp = Sequential()

mlp.add(Dense(units = n_hidden, activation = 'tanh',
              input_shape = (n_input, ), kernel_initializer='random_uniform',
              bias_initializer='zeros'))

mlp.add(Dense(units = n_output, activation = 'tanh',
              kernel_initializer='random_uniform',
              bias_initializer='zeros'))

mlp.compile(loss='mean_squared_error',optimizer=Adam(learning_rate=0.001),
            metrics=["accuracy"])

hist = mlp.fit(x_train, y_train, batch_size = 128, 
               epochs = 30, validation_data=(x_test,y_test),
               verbose=2)

res = mlp.evaluate(x_test, y_test, verbose=0)
print("정확률:", res[1]*100)

mlp.save('202016026_권지민_MNIST.keras')
# Out:
# (60000, 784)
# (60000, 10)
# Epoch 1/30
# /Users/test/Documents/kjm996/2024-2학기/AI-머신러닝/idk-tensorflow/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 469/469 - 1s - 3ms/step - accuracy: 0.8459 - loss: 0.0432 - val_accuracy: 0.9098 - val_loss: 0.0284
# Epoch 2/30
# 469/469 - 1s - 3ms/step - accuracy: 0.9282 - loss: 0.0227 - val_accuracy: 0.9426 - val_loss: 0.0186
# Epoch 3/30
# 469/469 - 1s - 3ms/step - accuracy: 0.9470 - loss: 0.0167 - val_accuracy: 0.9529 - val_loss: 0.0150
# Epoch 4/30
# 469/469 - 1s - 3ms/step - accuracy: 0.9563 - loss: 0.0139 - val_accuracy: 0.9574 - val_loss: 0.0132
# Epoch 5/30
# 469/469 - 1s - 3ms/step - accuracy: 0.9631 - loss: 0.0122 - val_accuracy: 0.9614 - val_loss: 0.0120
# Epoch 6/30
# 469/469 - 1s - 3ms/step - accuracy: 0.9671 - loss: 0.0110 - val_accuracy: 0.9645 - val_loss: 0.0109
# Epoch 7/30
# 469/469 - 1s - 3ms/step - accuracy: 0.9706 - loss: 0.0102 - val_accuracy: 0.9666 - val_loss: 0.0109
# Epoch 8/30
# 469/469 - 1s - 3ms/step - accuracy: 0.9736 - loss: 0.0094 - val_accuracy: 0.9685 - val_loss: 0.0100
# Epoch 9/30
# 469/469 - 1s - 3ms/step - accuracy: 0.9754 - loss: 0.0089 - val_accuracy: 0.9700 - val_loss: 0.0095
# Epoch 10/30
# 469/469 - 1s - 3ms/step - accuracy: 0.9771 - loss: 0.0085 - val_accuracy: 0.9702 - val_loss: 0.0092
# Epoch 11/30
# 469/469 - 1s - 3ms/step - accuracy: 0.9791 - loss: 0.0081 - val_accuracy: 0.9715 - val_loss: 0.0089
# Epoch 12/30
# 469/469 - 1s - 3ms/step - accuracy: 0.9806 - loss: 0.0077 - val_accuracy: 0.9716 - val_loss: 0.0087
# Epoch 13/30
# 469/469 - 1s - 3ms/step - accuracy: 0.9816 - loss: 0.0074 - val_accuracy: 0.9721 - val_loss: 0.0090
# Epoch 14/30
# 469/469 - 1s - 3ms/step - accuracy: 0.9828 - loss: 0.0071 - val_accuracy: 0.9735 - val_loss: 0.0083
# Epoch 15/30
# 469/469 - 1s - 3ms/step - accuracy: 0.9837 - loss: 0.0069 - val_accuracy: 0.9725 - val_loss: 0.0089
# Epoch 16/30
# 469/469 - 1s - 3ms/step - accuracy: 0.9847 - loss: 0.0068 - val_accuracy: 0.9749 - val_loss: 0.0086
# Epoch 17/30
# 469/469 - 1s - 3ms/step - accuracy: 0.9856 - loss: 0.0064 - val_accuracy: 0.9744 - val_loss: 0.0081
# Epoch 18/30
# 469/469 - 1s - 3ms/step - accuracy: 0.9860 - loss: 0.0063 - val_accuracy: 0.9739 - val_loss: 0.0085
# Epoch 19/30
# 469/469 - 1s - 3ms/step - accuracy: 0.9873 - loss: 0.0061 - val_accuracy: 0.9749 - val_loss: 0.0078
# Epoch 20/30
# 469/469 - 1s - 3ms/step - accuracy: 0.9878 - loss: 0.0059 - val_accuracy: 0.9749 - val_loss: 0.0081
# Epoch 21/30
# 469/469 - 1s - 3ms/step - accuracy: 0.9883 - loss: 0.0057 - val_accuracy: 0.9743 - val_loss: 0.0084
# Epoch 22/30
# 469/469 - 1s - 3ms/step - accuracy: 0.9890 - loss: 0.0056 - val_accuracy: 0.9746 - val_loss: 0.0079
# Epoch 23/30
# 469/469 - 1s - 3ms/step - accuracy: 0.9896 - loss: 0.0055 - val_accuracy: 0.9764 - val_loss: 0.0079
# Epoch 24/30
# 469/469 - 1s - 3ms/step - accuracy: 0.9900 - loss: 0.0054 - val_accuracy: 0.9754 - val_loss: 0.0076
# Epoch 25/30
# 469/469 - 1s - 3ms/step - accuracy: 0.9904 - loss: 0.0052 - val_accuracy: 0.9760 - val_loss: 0.0077
# Epoch 26/30
# 469/469 - 1s - 3ms/step - accuracy: 0.9909 - loss: 0.0051 - val_accuracy: 0.9769 - val_loss: 0.0076
# Epoch 27/30
# 469/469 - 1s - 3ms/step - accuracy: 0.9913 - loss: 0.0050 - val_accuracy: 0.9766 - val_loss: 0.0078
# Epoch 28/30
# 469/469 - 1s - 3ms/step - accuracy: 0.9917 - loss: 0.0049 - val_accuracy: 0.9751 - val_loss: 0.0077
# Epoch 29/30
# 469/469 - 1s - 3ms/step - accuracy: 0.9919 - loss: 0.0049 - val_accuracy: 0.9764 - val_loss: 0.0076
# Epoch 30/30
# 469/469 - 1s - 3ms/step - accuracy: 0.9922 - loss: 0.0047 - val_accuracy: 0.9760 - val_loss: 0.0075
# 정확률: 97.60000109672546
